# %%
import matplotlib.pyplot as plt

# %%
# read file into a list
with open('clouds/outputs_inter_over_Gf.csv', 'r') as f:
    dataGf = f.readlines()


# remove whitespace characters like `\n` at the end of each line
dataGf = [x.strip() for x in dataGf]

# remove the last element of the list
dataGf.pop()

# convert the list to a float list
dataGf = [float(i) for i in dataGf]

# reverse the list
dataGf.reverse()

plt.plot(dataGf)

# %%
# read file into a list
with open('clouds/outputs_inter_over_Gsk.csv', 'r') as f:
    dataGsk = f.readlines()


# remove whitespace characters like `\n` at the end of each line
dataGsk = [x.strip() for x in dataGsk]

# remove the last element of the list
dataGsk.pop()

# convert the list to a float list
dataGsk = [float(i) for i in dataGsk]

# reverse the list
dataGsk.reverse()

plt.plot(dataGsk)
